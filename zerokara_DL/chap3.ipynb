# %% [markdown]
# # 3章

# %% [markdown]
# ## 活性化関数の実装

# %% [markdown]
# ### シグモイド関数

# %%
function step_function(x)
    if x>0
        return 1
    else 0
    end
end
# Out:
# step_function (generic function with 1 method)

# %%
function sigmoid_function(x)
    return 1/(1+exp(-x))
end
# Out:
# sigmoid_function (generic function with 1 method)

# %%
x=(-10:0.1:10)
# Out:
# -10.0:0.1:10.0

# %%
using Plots

# %%
plot(
    x,
    [step_function.(x),sigmoid_function.(x)],
    xlims=(-10,10),
    label=["step_function" "sigmoid_function"],
    title="Step funcion & Sigmoid function",
    linewidth=2.5
)

# %% [markdown]
# ### ReLu関数

# %%
function ReLu_funciton(x)
    return max(0,x)
end
# Out:
# ReLu_funciton (generic function with 1 method)

# %%
plot(
    x, ReLu_funciton.(x),
    xlims=(-10,10),
    label="ReLu_function",
    linewidth=2.0
)

# %% [markdown]
# ## 行列計算

# %%
A=[
    1 2
    3 4
];
B=[
    5 6
    7 8
];

# %%
A*B
# Out:
# 2×2 Matrix{Int64}:
#  19  22
#  43  50

# %% [markdown]
# ## ニューラルネットワークの内積

# %%
X=[
    1 2
]
# Out:
# 1×2 Matrix{Int64}:
#  1  2

# %%
W=[
    1 3 5
    2 4 6
]
# Out:
# 2×3 Matrix{Int64}:
#  1  3  5
#  2  4  6

# %%
X*W
# Out:
# 1×3 Matrix{Int64}:
#  5  11  17

# %%
X=[1.0 0.5];
B1=[0.1 0.2 0.3];
W1=[0.1 0.3 0.5
0.2 0.4 0.6];

# %%
A1=X*W1+B1;
Z1=sigmoid_function.(A1);
println("A1=$A1")
println("Z1=$Z1")
# Out:
# A1=[0.30000000000000004 0.7 1.1]
# Z1=[0.574442516811659 0.6681877721681662 0.7502601055951177]

# %%
W2=[0.1 0.4
0.2 0.5
0.3 0.6];
B2=[0.1 0.2];

# %%
A2=A1*W2+B2;
Z2=sigmoid_function.(A2);
println("A2=$A2")
println("Z2=$Z2")
# Out:
# A2=[0.6 1.3299999999999998]
# Z2=[0.6456563062257954 0.7908406347869367]

# %% [markdown]
# ## ソフトマックス関数

# %%
function soft_max_function(x::Matrix)
    c=maximum(x)
    return exp.(x.-c)/sum(exp.(x.-c))
end
# Out:
# soft_max_function (generic function with 2 methods)

# %%
x=[0.3 2.9 4.0]
# Out:
# 1×3 Matrix{Float64}:
#  0.3  2.9  4.0

# %%
soft_max_function(x)
# Out:
# 1×3 Matrix{Float64}:
#  0.0182113  0.245192  0.736597
